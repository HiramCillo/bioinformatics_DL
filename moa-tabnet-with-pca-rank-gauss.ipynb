# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h1><font color = "red">DISCLAIMER</font></h1>
#     <p>The following notebook it's highly based on the works <a href = "https://www.kaggle.com/optimo/tabnetregressor-2-0-train-infer">TabNetRegressor 2.0 [TRAIN + INFER]</a>, <a href = "https://www.kaggle.com/liuhdme/moa-competition/data">MOA competition</a> and <a href = "https://www.kaggle.com/kushal1506/moa-pytorch-0-01859-rankgauss-pca-nn/data?select=train_targets_scored.csv">
# MoA | Pytorch | 0.01859 | RankGauss | PCA | NN</a>, please check it out.</p>
# </div>

# %% [markdown]
# # <font color = "seagreen">Preambule</font>
#
# I made this notebook to share some experiments (see the sections "Experiments") which could help to someone who don't want to waste their daily "submissions", but more importantly, to get feedback about what i could change to achive a better CV. Moreover, the easiness of TabNet to overfit the data it's disturbing, however i think that that model has potential. In the section "Conclusion" i share my opinion about the fine-tuning process of TabNet.

# %% [markdown]
# ## <font color = "green">Installing Libraries</font>

# %%
# TabNet
# !pip install --no-index --find-links /kaggle/input/pytorchtabnet/pytorch_tabnet-2.0.0-py3-none-any.whl pytorch-tabnet
# Iterative Stratification
# !pip install /kaggle/input/iterative-stratification/iterative-stratification-master/
# Out:
# Looking in links: /kaggle/input/pytorchtabnet/pytorch_tabnet-2.0.0-py3-none-any.whl
# Processing /kaggle/input/pytorchtabnet/pytorch_tabnet-2.0.0-py3-none-any.whl
# Requirement already satisfied: numpy<2.0,>=1.17 in /opt/conda/lib/python3.7/site-packages (from pytorch-tabnet) (1.18.5)
# Requirement already satisfied: tqdm<5.0,>=4.36 in /opt/conda/lib/python3.7/site-packages (from pytorch-tabnet) (4.45.0)
# Requirement already satisfied: torch<2.0,>=1.2 in /opt/conda/lib/python3.7/site-packages (from pytorch-tabnet) (1.6.0)
# Requirement already satisfied: scikit_learn>0.21 in /opt/conda/lib/python3.7/site-packages (from pytorch-tabnet) (0.23.2)
# Requirement already satisfied: scipy>1.4 in /opt/conda/lib/python3.7/site-packages (from pytorch-tabnet) (1.4.1)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch<2.0,>=1.2->pytorch-tabnet) (0.18.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit_learn>0.21->pytorch-tabnet) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit_learn>0.21->pytorch-tabnet) (0.14.1)
# Installing collected packages: pytorch-tabnet
# Successfully installed pytorch-tabnet-2.0.0
# Processing /kaggle/input/iterative-stratification/iterative-stratification-master
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from iterative-stratification==0.1.6) (1.18.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from iterative-stratification==0.1.6) (1.4.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from iterative-stratification==0.1.6) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->iterative-stratification==0.1.6) (0.14.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->iterative-stratification==0.1.6) (2.1.0)
# Building wheels for collected packages: iterative-stratification
#   Building wheel for iterative-stratification (setup.py) ... done
#   Created wheel for iterative-stratification: filename=iterative_stratification-0.1.6-py3-none-any.whl size=8401 sha256=9d17fe5dd15c3cb18e12cb6a71f2916835a18bde1bfbe3eae9351023852f5ac6
#   Stored in directory: /root/.cache/pip/wheels/b8/47/3f/eb4af42d124f37d23d6f13a4c8bbc32c1d70140e6e1cecb4aa
# Successfully built iterative-stratification
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.6

# %% [markdown]
# ## <font color = "green">Loading Libraries</font>

# %%
### General ###
import os
import sys
import copy
import tqdm
import pickle
import random
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../input/rank-gauss")
os.environ["CUDA_LAUNCH_BLOCKING"] = '1'

### Data Wrangling ###
import numpy as np
import pandas as pd
from scipy import stats
from gauss_rank_scaler import GaussRankScaler

### Data Visualization ###
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")

### Machine Learning ###
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score, log_loss
from sklearn.preprocessing import QuantileTransformer
from sklearn.feature_selection import VarianceThreshold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

### Deep Learning ###
import torch
from torch import nn
import torch.optim as optim
from torch.nn import functional as F
from torch.nn.modules.loss import _WeightedLoss
from torch.utils.data import DataLoader, Dataset
from torch.optim.lr_scheduler import ReduceLROnPlateau
# Tabnet 
from pytorch_tabnet.metrics import Metric
from pytorch_tabnet.tab_model import TabNetRegressor

### Make prettier the prints ###
from colorama import Fore
c_ = Fore.CYAN
m_ = Fore.MAGENTA
r_ = Fore.RED
b_ = Fore.BLUE
y_ = Fore.YELLOW
g_ = Fore.GREEN

# %% [markdown]
# ## <font color = "green">Reproducibility</font>

# %%
seed = 34

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
set_seed(seed)

# %% [markdown]
# ## <font color = "green">Configuration</font>

# %%
data_path = "../input/lish-moa/"
# Preprocessing and feature engineering
no_ctl = True
scale = "rankgauss"
variance_threshould = 0.7
decompo = "PCA"
ncompo_genes = 80
ncompo_cells = 10
encoding = "dummy"
# Training
MAX_EPOCH = 200

# %% [markdown]
# ## <font color = "green">Loading the Data</font>

# %%
train = pd.read_csv(data_path + "train_features.csv")
#train.drop(columns = ["sig_id"], inplace = True)

targets = pd.read_csv(data_path + "train_targets_scored.csv")
#train_targets_scored.drop(columns = ["sig_id"], inplace = True)

#train_targets_nonscored = pd.read_csv(data_path + "train_targets_nonscored.csv")

test = pd.read_csv(data_path + "test_features.csv")
#test.drop(columns = ["sig_id"], inplace = True)

submission = pd.read_csv(data_path + "sample_submission.csv")

# %% [markdown]
# # <font color = "seagreen">Preprocessing and Feature Engineering</font>

# %%
if no_ctl:
    # cp_type == ctl_vehicle
    print(b_, "not_ctl")
    train = train[train["cp_type"] != "ctl_vehicle"]
    test = test[test["cp_type"] != "ctl_vehicle"]
    targets = targets.iloc[train.index]
    train.reset_index(drop = True, inplace = True)
    test.reset_index(drop = True, inplace = True)
    targets.reset_index(drop = True, inplace = True)
# Out:
#  not_ctl

# %% [markdown]
# ## <font color = "green">Distributions Before Rank Gauss and PCA</font>

# %%
def distributions(num, graphs, items, features, gorc):
    """
    Plot the distributions of gene expression or cell viability data
    """
    for i in range(0, num - 1, 7):
        if i >= 3:
            break
        idxs = list(np.array([0, 1, 2, 3, 4, 5, 6]) + i)
    
        fig, axs = plt.subplots(1, 7, sharey = True)
        for k, item in enumerate(idxs):
            if item >= items:
                break
            graph = sns.distplot(train[features].values[:, item], ax = axs[k])
            graph.set_title(f"{gorc}-{item}")
            graphs.append(graph)

# %%
GENES = [col for col in train.columns if col.startswith("g-")]
CELLS = [col for col in train.columns if col.startswith("c-")]

# %% [markdown]
# ### <font color = "green">Distributions of the Train Set</font>

# %%
gnum = train[GENES].shape[1]
graphs = []

distributions(gnum, graphs, 771, GENES, "g")

# %%
cnum = train[CELLS].shape[1]
graphs = []

distributions(cnum, graphs, 100, CELLS, "c")

# %% [markdown]
# ### <font color = "green">Distributions of the Test Set</font>

# %%
gnum = test[GENES].shape[1]
graphs = []

distributions(gnum, graphs, 771, GENES, "g")

# %%
cnum = test[CELLS].shape[1]
graphs = []

distributions(cnum, graphs, 100, CELLS, "c")

# %% [markdown]
# ## <font color = "green">Rank Gauss Process</font>

# %%
data_all = pd.concat([train, test], ignore_index = True)
cols_numeric = [feat for feat in list(data_all.columns) if feat not in ["sig_id", "cp_type", "cp_time", "cp_dose"]]
mask = (data_all[cols_numeric].var() >= variance_threshould).values
tmp = data_all[cols_numeric].loc[:, mask]
data_all = pd.concat([data_all[["sig_id", "cp_type", "cp_time", "cp_dose"]], tmp], axis = 1)
cols_numeric = [feat for feat in list(data_all.columns) if feat not in ["sig_id", "cp_type", "cp_time", "cp_dose"]]

# %%
def scale_minmax(col):
    return (col - col.min()) / (col.max() - col.min())

def scale_norm(col):
    return (col - col.mean()) / col.std()

if scale == "boxcox":
    print(b_, "boxcox")
    data_all[cols_numeric] = data_all[cols_numeric].apply(scale_minmax, axis = 0)
    trans = []
    for feat in cols_numeric:
        trans_var, lambda_var = stats.boxcox(data_all[feat].dropna() + 1)
        trans.append(scale_minmax(trans_var))
    data_all[cols_numeric] = np.asarray(trans).T
    
elif scale == "norm":
    print(b_, "norm")
    data_all[cols_numeric] = data_all[cols_numeric].apply(scale_norm, axis = 0)
    
elif scale == "minmax":
    print(b_, "minmax")
    data_all[cols_numeric] = data_all[cols_numeric].apply(scale_minmax, axis = 0)
    
elif scale == "rankgauss":
    ### Rank Gauss ###
    print(b_, "Rank Gauss")
    scaler = GaussRankScaler()
    data_all[cols_numeric] = scaler.fit_transform(data_all[cols_numeric])
    
else:
    pass
# Out:
#  Rank Gauss

# %% [markdown]
# ## <font color = "green">Principal Component Analysis</font>

# %%
# PCA
if decompo == "PCA":
    print(b_, "PCA")
    GENES = [col for col in data_all.columns if col.startswith("g-")]
    CELLS = [col for col in data_all.columns if col.startswith("c-")]
    
    pca_genes = PCA(n_components = ncompo_genes,
                    random_state = seed).fit_transform(data_all[GENES])
    pca_cells = PCA(n_components = ncompo_cells,
                    random_state = seed).fit_transform(data_all[CELLS])
    
    pca_genes = pd.DataFrame(pca_genes, columns = [f"pca_g-{i}" for i in range(ncompo_genes)])
    pca_cells = pd.DataFrame(pca_cells, columns = [f"pca_c-{i}" for i in range(ncompo_cells)])
    data_all = pd.concat([data_all, pca_genes, pca_cells], axis = 1)
else:
    pass
# Out:
#  PCA

# %% [markdown]
# ## <font color = "green">One Hot</font>

# %%
# Encoding
if encoding == "lb":
    print(b_, "Label Encoding")
    for feat in ["cp_time", "cp_dose"]:
        data_all[feat] = LabelEncoder().fit_transform(data_all[feat])
elif encoding == "dummy":
    print(b_, "One-Hot")
    data_all = pd.get_dummies(data_all, columns = ["cp_time", "cp_dose"])
# Out:
#  One-Hot

# %%
GENES = [col for col in data_all.columns if col.startswith("g-")]
CELLS = [col for col in data_all.columns if col.startswith("c-")]

for stats in tqdm.tqdm(["sum", "mean", "std", "kurt", "skew"]):
    data_all["g_" + stats] = getattr(data_all[GENES], stats)(axis = 1)
    data_all["c_" + stats] = getattr(data_all[CELLS], stats)(axis = 1)    
    data_all["gc_" + stats] = getattr(data_all[GENES + CELLS], stats)(axis = 1)
# Out:
# 100%|██████████| 5/5 [00:05<00:00,  1.20s/it]

# %%
print(f"{b_}GENES' Lenght: {r_}{len(GENES)}")
print(f"{b_}CELLS' Lenght: {r_}{len(CELLS)}")
# Out:
# GENES' Lenght: 737
# CELLS' Lenght: 100

# %% [markdown]
# ## <font color = "green">Distributions After Rank Gauss and PCA</font>

# %%
def distributions(num, graphs, items, features, gorc):
    """
    Plot the distributions of gene expression or cell viability data
    """
    for i in range(0, num - 1, 7):
        if i >= 3:
            break
        idxs = list(np.array([0, 1, 2, 3, 4, 5, 6]) + i)
    
        fig, axs = plt.subplots(1, 7, sharey = True)
        for k, item in enumerate(idxs):
            if item >= items:
                break
            graph = sns.distplot(data_all[features].values[:, item], ax = axs[k])
            graph.set_title(f"{gorc}-{item}")
            graphs.append(graph)

# %% [markdown]
# ### <font color = "green">Distributions of "data_all"</font>

# %%
gnum = data_all[GENES].shape[1]
graphs = []

distributions(gnum, graphs, 737, GENES, "g")

# %%
cnum = data_all[CELLS].shape[1]
graphs = []

distributions(cnum, graphs, 100, CELLS, "c")

# %%
with open("data_all.pickle", "wb") as f:
    pickle.dump(data_all, f)

# %%
with open("data_all.pickle", "rb") as f:
    data_all = pickle.load(f)

# %%
# train_df and test_df
features_to_drop = ["sig_id", "cp_type"]
data_all.drop(features_to_drop, axis = 1, inplace = True)
try:
    targets.drop("sig_id", axis = 1, inplace = True)
except:
    pass
train_df = data_all[: train.shape[0]]
train_df.reset_index(drop = True, inplace = True)
# The following line it's a bad practice in my opinion, targets on train set
#train_df = pd.concat([train_df, targets], axis = 1)
test_df = data_all[train_df.shape[0]: ]
test_df.reset_index(drop = True, inplace = True)

# %%
print(f"{b_}train_df.shape: {r_}{train_df.shape}")
print(f"{b_}test_df.shape: {r_}{test_df.shape}")
# Out:
# train_df.shape: (21948, 947)
# test_df.shape: (3624, 947)

# %%
X_test = test_df.values
print(f"{b_}X_test.shape: {r_}{X_test.shape}")
# Out:
# X_test.shape: (3624, 947)

# %% [markdown]
# # <font color = "seagreen">Experiments</font>
#
# I just want to point that the [original work](https://www.kaggle.com/optimo/tabnetregressor-2-0-train-infer) achive a CV of 0.015532370835690834 and a LB score of 0.01864. Some of the experiments that i made with their changes:
#
#
# - CV: 0.01543560538566987, LB: 0.01858, best LB that i could achive, changes
#     - `n_a` = 32 instead of 24
#     - `n_d` = 32 instead of 24
# - CV: 0.015282077428722094, LB: 0.01862, best CV that i could achive, changes (Version 5):
#     - `n_a` = 32 instead of 24
#     - `n_d` = 32 instead of 24
#     - `virtual_batch_size` = 32, instead of 128
#     - `seed` = 42 instead of 0
# - CV: 0.015330138325308062, LB: 01864, the same LB that the original but better CV, changes:
#     - `n_a` = 32 instead of 24
#     - `n_d` = 32 instead of 24
#     - `virtual_batch_size` = 64, instead of 128
#     - `batch_size` = 512, instead of 1024
# - CV: 0.015361751699863063, LB: 0.01863, better LB and CV than the original, changes:
#     - `n_a` = 32 instead of 24
#     - `n_d` = 32 instead of 24
#     - `virtual_batch_size` = 64, instead of 128
# - CV: 0.015529925324634975, LB: 0.01865, changes:
#     - `n_a` = 48 instead of 24
#     - `n_d` = 48 instead of 24
# - CV: 0.015528553520924939, LB: 0.01868, changes:
#     - `n_a` = 12 instead of 24
#     - `n_d` = 12 instead of 24
# - CV: 0.015870202970324317, LB: 0.01876, worst CV and LB score, changes:
#     - `n_a` = 12 instead of 24
#     - `n_d` = 12 instead of 24
#     - `batch_size` = 2048, instead of 1024
#
#
# As you can see if `batch_size` < 1024 and > 1024 give worst results. Something similar happens with `n_a` and `n_d`, if their values are lower or higher than 32 the results are worst.
#
#
# ## <font color = "green">Versions</font>
#
# - **Version 5**: I added the `seed` parameter to the TabNet model.
# - **Version 6**: I changed the `virtual_batch_size` to 24
#     - CV: 0.01532900616425282, LB: 0.01862, changes:
#         - `n_a` = 32 instead of 24
#         - `n_d` = 32 instead of 24
#         - `virtual_batch_size` = 24, instead of 128
#         - `seed` = 42 instead of 0
# - **Version 7**: PCA, Rank Gauss, `virtual_batch_size` = 32, instead of 24
#     - CV: 0.016500671429559147, LB: 0.01848
# - **Version 8**: `sparsemax` instead of `entmax`
#     - CV: 0.016642308446397754, LB: 0.01854
# - **Version 9**: `entmax` instead of `sparsemax`, Reorganization of the code, submission.fillna(0.001, ...) instead of 0

# %% [markdown]
# # <font color = "seagreen">Training</font>
#
# Following the recomendation of [Optimo](https://www.kaggle.com/optimo) i've put the TabNet parameters inside the training loop.

# %% [markdown]
# ## <font color = "green">Custom Metric</font>

# %%
class LogitsLogLoss(Metric):
    """
    LogLoss with sigmoid applied
    """

    def __init__(self):
        self._name = "logits_ll"
        self._maximize = False

    def __call__(self, y_true, y_pred):
        """
        Compute LogLoss of predictions.

        Parameters
        ----------
        y_true: np.ndarray
            Target matrix or vector
        y_score: np.ndarray
            Score matrix or vector

        Returns
        -------
            float
            LogLoss of predictions vs targets.
        """
        logits = 1 / (1 + np.exp(-y_pred))
        aux = (1 - y_true) * np.log(1 - logits + 1e-15) + y_true * np.log(logits + 1e-15)
        return np.mean(-aux)

# %% [markdown]
# ## <font color = "green">Training Loop</font>

# %%
scores_auc_all = []
test_cv_preds = []

NB_SPLITS = 10 # 7
mskf = MultilabelStratifiedKFold(n_splits = NB_SPLITS, random_state = seed, shuffle = True)

oof_preds = []
oof_targets = []
scores = []
scores_auc = []

# %%
for fold_nb, (train_idx, val_idx) in enumerate(mskf.split(train_df, targets)):
    print(b_,"FOLDS: ", r_, fold_nb + 1)
    print(g_, '*' * 60, c_)
    
    X_train, y_train = train_df.values[train_idx, :], targets.values[train_idx, :]
    X_val, y_val = train_df.values[val_idx, :], targets.values[val_idx, :]
    
    ### Model Parameters ###
    # n_d and n_a are different from the original work, 32 instead of 24
    # This is the first change in the code from the original
    tabnet_params = dict(
        n_d = 32,
        n_a = 32,
        n_steps = 1,
        gamma = 1.3,
        lambda_sparse = 0,
        optimizer_fn = optim.Adam,
        optimizer_params = dict(lr = 2e-2, weight_decay = 1e-5),
        mask_type = "entmax",
        scheduler_params = dict(
            mode = "min", patience = 5, min_lr = 1e-5, factor = 0.9),
        scheduler_fn = ReduceLROnPlateau,
        seed = seed,
        verbose = 10
    )
    
    ### Model ###
    model = TabNetRegressor(**tabnet_params)
        
    ### Fit ###
    # Another change to the original code
    # virtual_batch_size of 32 instead of 128
    # I added the metric for Label Smoothing 
    model.fit(
        X_train = X_train,
        y_train = y_train,
        eval_set = [(X_val, y_val)],
        eval_name = ["val"],
        eval_metric = ["logits_ll"],
        max_epochs = MAX_EPOCH,
        patience = 20,
        batch_size = 1024, 
        virtual_batch_size = 32,
        num_workers = 1,
        drop_last = False,
        # To use binary cross entropy because this is not a regression problem
        loss_fn = F.binary_cross_entropy_with_logits
    )
    print(y_, '-' * 60)
    
    ### Predict on validation ###
    preds_val = model.predict(X_val)
    # Apply sigmoid to the predictions
    preds = 1 / (1 + np.exp(-preds_val))
    score = np.min(model.history["val_logits_ll"])
    
    ### Save OOF for CV ###
    oof_preds.append(preds_val)
    oof_targets.append(y_val)
    scores.append(score)
    
    ### Predict on test ###
    preds_test = model.predict(X_test)
    test_cv_preds.append(1 / (1 + np.exp(-preds_test)))

oof_preds_all = np.concatenate(oof_preds)
oof_targets_all = np.concatenate(oof_targets)
test_preds_all = np.stack(test_cv_preds)
# Out:
#  FOLDS:   1
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.30819 | val_logits_ll: 0.02847 |  0:00:03s
# epoch 10 | loss: 0.01932 | val_logits_ll: 0.01881 |  0:00:33s
# epoch 20 | loss: 0.01756 | val_logits_ll: 0.02018 |  0:01:03s
# epoch 30 | loss: 0.01718 | val_logits_ll: 0.0183  |  0:01:33s
# epoch 40 | loss: 0.01677 | val_logits_ll: 0.01847 |  0:02:03s
# epoch 50 | loss: 0.01668 | val_logits_ll: 0.01709 |  0:02:33s
# epoch 60 | loss: 0.01625 | val_logits_ll: 0.01694 |  0:03:04s
# epoch 70 | loss: 0.0161  | val_logits_ll: 0.01685 |  0:03:33s
# epoch 80 | loss: 0.01589 | val_logits_ll: 0.01688 |  0:04:03s
# epoch 90 | loss: 0.01571 | val_logits_ll: 0.01683 |  0:04:33s
# epoch 100| loss: 0.01543 | val_logits_ll: 0.01674 |  0:05:03s
# epoch 110| loss: 0.0155  | val_logits_ll: 0.01674 |  0:05:33s
# epoch 120| loss: 0.0151  | val_logits_ll: 0.01676 |  0:06:03s
# epoch 130| loss: 0.01482 | val_logits_ll: 0.01686 |  0:06:32s
# epoch 140| loss: 0.01462 | val_logits_ll: 0.01695 |  0:07:02s
#
# Early stopping occured at epoch 142 with best_epoch = 122 and best_val_logits_ll = 0.01664
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------
#  FOLDS:   2
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.31427 | val_logits_ll: 0.02893 |  0:00:02s
# epoch 10 | loss: 0.01879 | val_logits_ll: 0.01864 |  0:00:32s
# epoch 20 | loss: 0.01729 | val_logits_ll: 0.01779 |  0:01:03s
# epoch 30 | loss: 0.01687 | val_logits_ll: 0.01936 |  0:01:33s
# epoch 40 | loss: 0.01657 | val_logits_ll: 0.01721 |  0:02:03s
# epoch 50 | loss: 0.01634 | val_logits_ll: 0.01682 |  0:02:33s
# epoch 60 | loss: 0.01617 | val_logits_ll: 0.01689 |  0:03:02s
# epoch 70 | loss: 0.01596 | val_logits_ll: 0.01656 |  0:03:31s
# epoch 80 | loss: 0.01573 | val_logits_ll: 0.01649 |  0:04:01s
# epoch 90 | loss: 0.01554 | val_logits_ll: 0.01653 |  0:04:31s
# epoch 100| loss: 0.01534 | val_logits_ll: 0.01654 |  0:05:01s
# epoch 110| loss: 0.01487 | val_logits_ll: 0.01667 |  0:05:31s
#
# Early stopping occured at epoch 116 with best_epoch = 96 and best_val_logits_ll = 0.01647
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------
#  FOLDS:   3
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.30999 | val_logits_ll: 0.02844 |  0:00:02s
# epoch 10 | loss: 0.01919 | val_logits_ll: 0.01917 |  0:00:33s
# epoch 20 | loss: 0.01772 | val_logits_ll: 0.01847 |  0:01:03s
# epoch 30 | loss: 0.01732 | val_logits_ll: 0.01747 |  0:01:33s
# epoch 40 | loss: 0.01689 | val_logits_ll: 0.01736 |  0:02:03s
# epoch 50 | loss: 0.01668 | val_logits_ll: 0.0172  |  0:02:33s
# epoch 60 | loss: 0.0165  | val_logits_ll: 0.01715 |  0:03:04s
# epoch 70 | loss: 0.01637 | val_logits_ll: 0.01685 |  0:03:34s
# epoch 80 | loss: 0.01616 | val_logits_ll: 0.01674 |  0:04:04s
# epoch 90 | loss: 0.01595 | val_logits_ll: 0.01666 |  0:04:34s
# epoch 100| loss: 0.01572 | val_logits_ll: 0.01672 |  0:05:04s
# epoch 110| loss: 0.01548 | val_logits_ll: 0.01662 |  0:05:34s
# epoch 120| loss: 0.01526 | val_logits_ll: 0.01671 |  0:06:04s
#
# Early stopping occured at epoch 122 with best_epoch = 102 and best_val_logits_ll = 0.01652
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------
#  FOLDS:   4
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.3119  | val_logits_ll: 0.02789 |  0:00:03s
# epoch 10 | loss: 0.01876 | val_logits_ll: 0.02064 |  0:00:35s
# epoch 20 | loss: 0.01772 | val_logits_ll: 0.01837 |  0:01:08s
# epoch 30 | loss: 0.01704 | val_logits_ll: 0.01694 |  0:01:40s
# epoch 40 | loss: 0.01687 | val_logits_ll: 0.01678 |  0:02:12s
# epoch 50 | loss: 0.01665 | val_logits_ll: 0.01655 |  0:02:44s
# epoch 60 | loss: 0.01667 | val_logits_ll: 0.0167  |  0:03:16s
# epoch 70 | loss: 0.01628 | val_logits_ll: 0.01633 |  0:03:48s
# epoch 80 | loss: 0.01599 | val_logits_ll: 0.01627 |  0:04:19s
# epoch 90 | loss: 0.01574 | val_logits_ll: 0.01634 |  0:04:50s
#
# Early stopping occured at epoch 94 with best_epoch = 74 and best_val_logits_ll = 0.01608
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------
#  FOLDS:   5
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.31017 | val_logits_ll: 0.02853 |  0:00:03s
# epoch 10 | loss: 0.01895 | val_logits_ll: 0.01941 |  0:00:34s
# epoch 20 | loss: 0.01735 | val_logits_ll: 0.02143 |  0:01:02s
# epoch 30 | loss: 0.01697 | val_logits_ll: 0.01758 |  0:01:31s
# epoch 40 | loss: 0.01665 | val_logits_ll: 0.01722 |  0:01:59s
# epoch 50 | loss: 0.01628 | val_logits_ll: 0.01718 |  0:02:28s
# epoch 60 | loss: 0.01604 | val_logits_ll: 0.01679 |  0:02:57s
# epoch 70 | loss: 0.01593 | val_logits_ll: 0.017   |  0:03:26s
# epoch 80 | loss: 0.01554 | val_logits_ll: 0.01676 |  0:03:54s
# epoch 90 | loss: 0.01544 | val_logits_ll: 0.01678 |  0:04:23s
#
# Early stopping occured at epoch 99 with best_epoch = 79 and best_val_logits_ll = 0.01662
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------
#  FOLDS:   6
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.31035 | val_logits_ll: 0.02832 |  0:00:02s
# epoch 10 | loss: 0.01874 | val_logits_ll: 0.01877 |  0:00:31s
# epoch 20 | loss: 0.01738 | val_logits_ll: 0.01755 |  0:00:59s
# epoch 30 | loss: 0.01691 | val_logits_ll: 0.01748 |  0:01:27s
# epoch 40 | loss: 0.01671 | val_logits_ll: 0.01701 |  0:01:56s
# epoch 50 | loss: 0.01646 | val_logits_ll: 0.01709 |  0:02:24s
# epoch 60 | loss: 0.01617 | val_logits_ll: 0.01702 |  0:02:53s
# epoch 70 | loss: 0.01595 | val_logits_ll: 0.01679 |  0:03:21s
# epoch 80 | loss: 0.0158  | val_logits_ll: 0.01674 |  0:03:49s
# epoch 90 | loss: 0.01546 | val_logits_ll: 0.0167  |  0:04:17s
# epoch 100| loss: 0.01531 | val_logits_ll: 0.01678 |  0:04:46s
# epoch 110| loss: 0.01511 | val_logits_ll: 0.01704 |  0:05:14s
#
# Early stopping occured at epoch 113 with best_epoch = 93 and best_val_logits_ll = 0.01663
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------
#  FOLDS:   7
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.30784 | val_logits_ll: 0.02803 |  0:00:02s
# epoch 10 | loss: 0.0188  | val_logits_ll: 0.02029 |  0:00:30s
# epoch 20 | loss: 0.01768 | val_logits_ll: 0.01799 |  0:00:59s
# epoch 30 | loss: 0.0173  | val_logits_ll: 0.01791 |  0:01:27s
# epoch 40 | loss: 0.017   | val_logits_ll: 0.01746 |  0:01:55s
# epoch 50 | loss: 0.01672 | val_logits_ll: 0.01692 |  0:02:22s
# epoch 60 | loss: 0.01644 | val_logits_ll: 0.01682 |  0:02:50s
# epoch 70 | loss: 0.01605 | val_logits_ll: 0.01677 |  0:03:19s
# epoch 80 | loss: 0.0159  | val_logits_ll: 0.01665 |  0:03:47s
# epoch 90 | loss: 0.01574 | val_logits_ll: 0.01661 |  0:04:15s
# epoch 100| loss: 0.01545 | val_logits_ll: 0.01653 |  0:04:43s
# epoch 110| loss: 0.01527 | val_logits_ll: 0.01651 |  0:05:11s
# epoch 120| loss: 0.01504 | val_logits_ll: 0.01659 |  0:05:39s
# epoch 130| loss: 0.01463 | val_logits_ll: 0.01665 |  0:06:07s
#
# Early stopping occured at epoch 130 with best_epoch = 110 and best_val_logits_ll = 0.01651
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------
#  FOLDS:   8
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.30854 | val_logits_ll: 0.02797 |  0:00:02s
# epoch 10 | loss: 0.01872 | val_logits_ll: 0.01875 |  0:00:30s
# epoch 20 | loss: 0.01759 | val_logits_ll: 0.01813 |  0:00:59s
# epoch 30 | loss: 0.01706 | val_logits_ll: 0.01731 |  0:01:26s
# epoch 40 | loss: 0.0167  | val_logits_ll: 0.01711 |  0:01:55s
# epoch 50 | loss: 0.01654 | val_logits_ll: 0.01689 |  0:02:22s
# epoch 60 | loss: 0.0163  | val_logits_ll: 0.01703 |  0:02:50s
# epoch 70 | loss: 0.01605 | val_logits_ll: 0.01681 |  0:03:18s
# epoch 80 | loss: 0.01595 | val_logits_ll: 0.01672 |  0:03:46s
#
# Early stopping occured at epoch 82 with best_epoch = 62 and best_val_logits_ll = 0.01665
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------
#  FOLDS:   9
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.31213 | val_logits_ll: 0.02857 |  0:00:02s
# epoch 10 | loss: 0.01886 | val_logits_ll: 0.01867 |  0:00:31s
# epoch 20 | loss: 0.01761 | val_logits_ll: 0.02102 |  0:00:59s
# epoch 30 | loss: 0.01711 | val_logits_ll: 0.01748 |  0:01:26s
# epoch 40 | loss: 0.01696 | val_logits_ll: 0.01886 |  0:01:54s
# epoch 50 | loss: 0.01659 | val_logits_ll: 0.01714 |  0:02:22s
# epoch 60 | loss: 0.0164  | val_logits_ll: 0.01684 |  0:02:50s
# epoch 70 | loss: 0.01628 | val_logits_ll: 0.01675 |  0:03:18s
# epoch 80 | loss: 0.0161  | val_logits_ll: 0.01674 |  0:03:46s
# epoch 90 | loss: 0.01603 | val_logits_ll: 0.01675 |  0:04:14s
# epoch 100| loss: 0.01579 | val_logits_ll: 0.0167  |  0:04:42s
# epoch 110| loss: 0.01558 | val_logits_ll: 0.01662 |  0:05:10s
# epoch 120| loss: 0.0155  | val_logits_ll: 0.01662 |  0:05:38s
#
# Early stopping occured at epoch 128 with best_epoch = 108 and best_val_logits_ll = 0.01653
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------
#  FOLDS:   10
#  ************************************************************
# Device used : cuda
# epoch 0  | loss: 0.31163 | val_logits_ll: 0.02894 |  0:00:02s
# epoch 10 | loss: 0.0189  | val_logits_ll: 0.0186  |  0:00:31s
# epoch 20 | loss: 0.01747 | val_logits_ll: 0.02092 |  0:00:59s
# epoch 30 | loss: 0.017   | val_logits_ll: 0.01733 |  0:01:27s
# epoch 40 | loss: 0.01682 | val_logits_ll: 0.01713 |  0:01:55s
# epoch 50 | loss: 0.01657 | val_logits_ll: 0.01717 |  0:02:24s
# epoch 60 | loss: 0.01634 | val_logits_ll: 0.01678 |  0:02:52s
# epoch 70 | loss: 0.01628 | val_logits_ll: 0.01667 |  0:03:21s
# epoch 80 | loss: 0.01601 | val_logits_ll: 0.01664 |  0:03:50s
# epoch 90 | loss: 0.01568 | val_logits_ll: 0.01681 |  0:04:18s
# epoch 100| loss: 0.0156  | val_logits_ll: 0.0165  |  0:04:46s
# epoch 110| loss: 0.0152  | val_logits_ll: 0.01649 |  0:05:15s
# epoch 120| loss: 0.01499 | val_logits_ll: 0.01672 |  0:05:44s
#
# Early stopping occured at epoch 123 with best_epoch = 103 and best_val_logits_ll = 0.01648
# Best weights from best epoch are automatically used!
#  ------------------------------------------------------------

# %% [markdown]
# # <font color = "seagreen">Results</font>

# %%
aucs = []
for task_id in range(oof_preds_all.shape[1]):
    aucs.append(roc_auc_score(y_true = oof_targets_all[:, task_id],
                              y_score = oof_preds_all[:, task_id]
                             ))
print(f"{b_}Overall AUC: {r_}{np.mean(aucs)}")
print(f"{b_}Average CV: {r_}{np.mean(scores)}")
# Out:
# Overall AUC: 0.7554719444487887
# Average CV: 0.016512674879870078

# %% [markdown]
# ## <font color = "green">Post-processing</font>

# %%
all_feat = [col for col in submission.columns if col not in ["sig_id"]]
# To obtain the same lenght of test_preds_all and submission
test = pd.read_csv(data_path + "test_features.csv")
sig_id = test[test["cp_type"] != "ctl_vehicle"].sig_id.reset_index(drop = True)
tmp = pd.DataFrame(test_preds_all.mean(axis = 0), columns = all_feat)
tmp["sig_id"] = sig_id

submission = pd.merge(test[["sig_id"]], tmp, on = "sig_id", how = "left")
submission.fillna(0, inplace = True)

# %% [markdown]
# ## <font color = "green">Submission</font>

# %%
#submission[all_feat] = tmp.mean(axis = 0)

# Set control to 0
#submission.loc[test["cp_type"] == 0, submission.columns[1:]] = 0
submission.to_csv("submission.csv", index = None)
print(f"{b_}submission.shape: {r_}{submission.shape}")
# Out:
# submission.shape: (3982, 207)

# %%
submission.head()
# Out:
#          sig_id  5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  \
# 0  id_0004d9e33                     0.000999                0.001230
# 1  id_001897cda                     0.000535                0.000772
# 2  id_002429b5b                     0.000000                0.000000
# 3  id_00276f245                     0.000854                0.000898
# 4  id_0027f1083                     0.001685                0.001472
#
#    acat_inhibitor  acetylcholine_receptor_agonist  \
# 0        0.001856                        0.017705
# 1        0.001951                        0.002324
# 2        0.000000                        0.000000
# 3        0.001760                        0.012562
# 4        0.001593                        0.013469
#
#    acetylcholine_receptor_antagonist  acetylcholinesterase_inhibitor  \
# 0                           0.020885                        0.005390
# 1                           0.001619                        0.002076
# 2                           0.000000                        0.000000
# 3                           0.017579                        0.004415
# 4                           0.022022                        0.005215
#
#    adenosine_receptor_agonist  adenosine_receptor_antagonist  \
# 0                    0.004138                       0.005195
# 1                    0.002884                       0.008992
# 2                    0.000000                       0.000000
# 3                    0.003095                       0.004086
# 4                    0.003283                       0.002834
#
#    adenylyl_cyclase_activator  ...  tropomyosin_receptor_kinase_inhibitor  \
# 0                    0.000345  ...                               0.000791
# 1                    0.002120  ...                               0.000896
# 2                    0.000000  ...                               0.000000
# 3                    0.000223  ...                               0.000671
# 4                    0.000383  ...                               0.000688
#
#    trpv_agonist  trpv_antagonist  tubulin_inhibitor  \
# 0      0.001386         0.004036           0.000855
# 1      0.001135         0.002606           0.000447
# 2      0.000000         0.000000           0.000000
# 3      0.001910         0.002366           0.011448
# 4      0.000867         0.003306           0.001671
#
#    tyrosine_kinase_inhibitor  ubiquitin_specific_protease_inhibitor  \
# 0                   0.000729                               0.000578
# 1                   0.007260                               0.000563
# 2                   0.000000                               0.000000
# 3                   0.003062                               0.000603
# 4                   0.001431                               0.000707
#
#    vegfr_inhibitor  vitamin_b  vitamin_d_receptor_agonist  wnt_inhibitor
# 0         0.000685   0.001940                    0.011394       0.001916
# 1         0.008278   0.001407                    0.005943       0.002953
# 2         0.000000   0.000000                    0.000000       0.000000
# 3         0.001616   0.001853                    0.000384       0.001434
# 4         0.001062   0.001904                    0.000515       0.001834
#
# [5 rows x 207 columns]

# %% [markdown]
# # <font color = "seagreen">Conclusion</font>
# The number 32 is key for two paramaters, `n_a` and `n_d`, also for the hyperparameter `virtual_batch_size`, numbers higher or lower than that number gives worst results. As you can see, a huge improvement on **LB** (compared to Version 6) was possible using **PCA** and **Rank Gauss** but the **CV** it's a way worst than the previos. This just reafirms the idea that it's too easy to overfit the data with **TabNet**.

# %% [markdown]
# <div class = "alert alert-block alert-info">
#     <h3><font color = "red">NOTE: </font></h3>
#     <p>If you want to comment please tag me with '@' to answer more quickly.</p>
# </div>
